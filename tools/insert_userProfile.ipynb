# %%
import pandas as pd
import boto3
from botocore.config import Config
import os
from faker import Faker
from dotenv import load_dotenv
load_dotenv()
from datetime import datetime
import numpy as np
fake = Faker(['it_IT', 'en_US', 'ja_JP','zh_CN','zh_TW'])

# %%
my_config = Config(
    region_name = 'us-west-1',
    signature_version = 'v4',
    retries = {
        'max_attempts': 10,
        'mode': 'standard'
    }
)

# %%
client = boto3.client(
    'dynamodb',
    aws_access_key_id=os.getenv('awsAccessKeyId'),
    aws_secret_access_key=os.getenv('awsSecretAccessKey'),
    config=my_config)
dynamodb = boto3.resource(
    'dynamodb',
    aws_access_key_id=os.getenv('awsAccessKeyId'),
    aws_secret_access_key=os.getenv('awsSecretAccessKey'),
    config=my_config)
ddb_exceptions = client.exceptions

# %%
userInfoTable = dynamodb.Table('UserInfo-7jzw3fqlhrcuzaarveonxbtczq-prod')

# %%
import json

# %%
dict11="""{
   "Users":[
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"189df196-3a4f-4fc2-abfb-3d9befb10d9e"
            },
            {
               "Name":"email_verified",
               "Value":"false"
            },
            {
               "Name":"custom:Phone",
               "Value":"6476866618"
            },
            {
               "Name":"email",
               "Value":"mysoho661@gmail.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.652026012262E9,
         "UserLastModifiedDate":1.652026012262E9,
         "UserStatus":"UNCONFIRMED",
         "Username":"189df196-3a4f-4fc2-abfb-3d9befb10d9e"
      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"2b5d7d36-d389-4b43-97e0-f31d3b5062d2"
            },
            {
               "Name":"email_verified",
               "Value":"true"
            },
            {
               "Name":"custom:Phone",
               "Value":"2019533373"
            },
            {
               "Name":"email",
               "Value":"milanac20dong@aol.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.65175654907E9,
         "UserLastModifiedDate":1.651756733143E9,
         "UserStatus":"CONFIRMED",
         "Username":"2b5d7d36-d389-4b43-97e0-f31d3b5062d2"
      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"2bdac403-5636-4c33-bb68-0106d4be47d4"
            },
            {
               "Name":"email_verified",
               "Value":"true"
            },
            {
               "Name":"custom:Phone",
               "Value":"6476496888"
            },
            {
               "Name":"email",
               "Value":"ssuperfjy@gmail.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.651184220426E9,
         "UserLastModifiedDate":1.6511842325E9,
         "UserStatus":"CONFIRMED",
         "Username":"2bdac403-5636-4c33-bb68-0106d4be47d4"
      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"36ecdce2-d36f-4c38-9843-9e8d6abd3183"
            },
            {
               "Name":"email_verified",
               "Value":"true"
            },
            {
               "Name":"custom:Phone",
               "Value":"+16479973519"
            },
            {
               "Name":"email",
               "Value":"yuejiayi0826@163.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.651925270733E9,
         "UserLastModifiedDate":1.65192540965E9,
         "UserStatus":"CONFIRMED",
         "Username":"36ecdce2-d36f-4c38-9843-9e8d6abd3183"
      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"3e9d5586-a6a1-4fc3-bec0-de9a3cde245e"
            },
            {
               "Name":"email_verified",
               "Value":"true"
            },
            {
               "Name":"custom:Phone",
               "Value":"6478710781"
            },
            {
               "Name":"email",
               "Value":"shushengacademy001@gmail.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.652120042224E9,
         "UserLastModifiedDate":1.652120050897E9,
         "UserStatus":"CONFIRMED",
         "Username":"3e9d5586-a6a1-4fc3-bec0-de9a3cde245e"
      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"3f5f38c5-9b37-4c47-bdef-55cedb70111a"
            },
            {
               "Name":"email_verified",
               "Value":"true"
            },
            {
               "Name":"custom:Phone",
               "Value":"18558888899"
            },
            {
               "Name":"email",
               "Value":"1719116555@qq.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.651924015105E9,
         "UserLastModifiedDate":1.651924044079E9,
         "UserStatus":"CONFIRMED",
         "Username":"3f5f38c5-9b37-4c47-bdef-55cedb70111a"
      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"42994de1-3aeb-4ec9-9999-8a1ac0a7853f"
            },
            {
               "Name":"email_verified",
               "Value":"true"
            },
            {
               "Name":"custom:Phone",
               "Value":

      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"d735df35-48c8-40a0-8e23-5f93106eb053"
            },
            {
               "Name":"email_verified",
               "Value":"true"
            },
            {
               "Name":"custom:Phone",
               "Value":"6472011055"
            },
            {
               "Name":"email",
               "Value":"Anita.sbw@gmail.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.651161109114E9,
         "UserLastModifiedDate":1.651161142584E9,
         "UserStatus":"CONFIRMED",
         "Username":"d735df35-48c8-40a0-8e23-5f93106eb053"
      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"d7794a43-223c-4df8-9c62-fbb7bd01e26b"
            },
            {
               "Name":"email_verified",
               "Value":"true"
            },
            {
               "Name":"custom:Phone",
               "Value":"13609300066"
            },
            {
               "Name":"email",
               "Value":"F_jie1124@163.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.651138417898E9,
         "UserLastModifiedDate":1.65113843721E9,
         "UserStatus":"CONFIRMED",
         "Username":"d7794a43-223c-4df8-9c62-fbb7bd01e26b"
      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"eb0b06d0-28a8-4598-95db-8fe133400709"
            },
            {
               "Name":"email_verified",
               "Value":"false"
            },
            {
               "Name":"custom:Phone",
               "Value":"423333"
            },
            {
               "Name":"email",
               "Value":"yangbn2008@gmail.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.652028939439E9,
         "UserLastModifiedDate":1.652028939439E9,
         "UserStatus":"UNCONFIRMED",
         "Username":"eb0b06d0-28a8-4598-95db-8fe133400709"
      },
      {
         "Attributes":[
            {
               "Name":"sub",
               "Value":"f75559ac-9a2c-4f61-b25e-8765a2b392f8"
            },
            {
               "Name":"email_verified",
               "Value":"true"
            },
            {
               "Name":"custom:Phone",
               "Value":"2269897183"
            },
            {
               "Name":"email",
               "Value":"metroantique@gmail.com"
            }
         ],
         "Enabled":true,
         "UserCreateDate":1.651158821356E9,
         "UserLastModifiedDate":1.651158832008E9,
         "UserStatus":"CONFIRMED",
         "Username":"f75559ac-9a2c-4f61-b25e-8765a2b392f8"
      }
   ]
}"""

# %%
json_dict = json.loads(dict11)

# %%
for i in json_dict['Users']:
    #print('username:',i['Attributes'][0]['Value'])
    #print('phone',i['Attributes'][2]['Value'])
    print('email',i['Attributes'][3]['Value'])
# Out:
# email mysoho661@gmail.com
# email milanac20dong@aol.com
# email ssuperfjy@gmail.com
# email yuejiayi0826@163.com
# email shushengacademy001@gmail.com
# email 1719116555@qq.com
# email yangliu0918@gmail.com
# email jane04222003@hotmail.com
# email mgzhong168@gmail.com
# email Andy.6618@hotmail.com
# email shushengacademy@gmail.com
# email yizhouz@hotmail.com
# email lty9411@yahoo.ca
# email shushen2013@gmail.com
# email scarlettyin97@gmail.com
# email 972848314@qq.com
# email Anita.sbw@gmail.com
# email F_jie1124@163.com
# email yangbn2008@gmail.com
# email metroantique@gmail.com

# %%
for i in (json_dict['Users']):
    createdAt=datetime.now().strftime("%Y-%m-%dT%H:%M:%S.000Z")
    randomID=fake.uuid4()
    auctionItemData={'__typename': 'UserInfo',
    'id':randomID,
    'email':i['Attributes'][3]['Value'],
    'userName':i['Attributes'][0]['Value'],
    'phone':i['Attributes'][2]['Value'],
    'createdAt':createdAt,
    'updatedAt':createdAt
    }

    print('上传auctionitem 开始')
    response = userInfoTable.put_item(Item=auctionItemData)
    print('上传auctionitem 结束')
# Out:
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
# 上传auctionitem 开始
# 上传auctionitem 结束
