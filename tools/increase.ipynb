# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\shush\Documents\GitHub\bhpmJS\tools\bid_increment.xlsx')

# %%
list1 = df[0].to_list()

# %%
for i in list1:
    print(f"""\"{i}\",""")
# Out:
# "100",
# "200",
# "300",
# "400",
# "500",
# "600",
# "700",
# "800",
# "900",
# "1000",
# "1100",
# "1200",
# "1300",
# "1400",
# "1500",
# "1600",
# "1700",
# "1800",
# "1900",
# "2000",
# "2200",
# "2400",
# "2600",
# "2800",
# "3000",
# "3200",
# "3400",
# "3600",
# "3800",
# "4000",
# "4200",
# "4400",
# "4600",
# "4800",
# "5000",
# "5500",
# "6000",
# "6500",
# "7000",
# "7500",
# "8000",
# "8500",
# "9000",
# "9500",
# "10000",
# "11000",
# "12000",
# "13000",
# "14000",
# "15000",
# "16000",
# "17000",
# "18000",
# "19000",
# "20000",
# "22000",
# "24000",
# "26000",
# "28000",
# "30000",
# "32000",
# "34000",
# "36000",
# "38000",
# "40000",
# "42000",
# "44000",
# "46000",
# "48000",
# "50000",
# "55000",
# "60000",
# "65000",
# "70000",
# "75000",
# "80000",
# "85000",
# "90000",
# "95000",
# "100000",
# "110000",
# "120000",
# "130000",
# "140000",
# "150000",
# "160000",
# "170000",
# "180000",
# "190000",
# "200000",
# "210000",
# "220000",
# "230000",
# "240000",
# ...
