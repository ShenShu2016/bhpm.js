# %%
import pandas as pd
import boto3
from botocore.config import Config
import os
from faker import Faker
from dotenv import load_dotenv
load_dotenv()
from datetime import datetime
import numpy as np

# %%
df=pd.read_excel(r'C:\Users\Shen\Documents\GitHub\bhpmJS\tools\auction002.xlsb')

# %%
df
# Out:
#      lot          title  startingPrice  estimatedPriceMin  estimatedPriceMax  \
# 0      1     民國 粉彩仕女提梁壺            100                150                200
# 1      2     十八世紀 和田青玉獾            100                150                240
# 2      3           大日唐卡            200                300                400
# 3      4             唐卡            200                250                300
# 4      5           金剛唐卡            200                250                300
# ..   ...            ...            ...                ...                ...
# 203  204  新石器時代 齊家雙耳大陶罐           1400               1700               3200
# 204  205   新石器時代 齊家雙耳陶罐            300                400                800
# 205  206     民國 朱泥蘭花鉢一對            200                300                400
# 206  207  民國 梅蘭竹菊老紫砂小花盆            400                500                800
# 207  208     清末 景德鎮童子筆筒            300                320                500
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   lot                208 non-null    int64
#  1   title              208 non-null    object
#  2   startingPrice      208 non-null    int64
#  3   estimatedPriceMin  208 non-null    int64
#  4   estimatedPriceMax  208 non-null    int64
#  5   description        208 non-null    object
#  6   titleEng           208 non-null    object
#  7   descriptionEng     208 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 13.1+ KB

# %%
# Replace all Nan values to empty string
df = df.replace(np.nan, '', regex=True)

# %%
fileList=os.listdir(r'auctionInfo2/')
fileList
# Out:
# ['100_1.jpg',
#  '100_10.jpg',
#  '100_11.jpg',
#  '100_12.jpg',
#  '100_13.jpg',
#  '100_14.jpg',
#  '100_2.jpg',
#  '100_3.jpg',
#  '100_4.jpg',
#  '100_5.jpg',
#  '100_6.jpg',
#  '100_7.jpg',
#  '100_8.jpg',
#  '100_9.jpg',
#  '101_1.jpg',
#  '101_10.jpg',
#  '101_11.jpg',
#  '101_12.jpg',
#  '101_2.jpg',
#  '101_3.jpg',
#  '101_4.jpg',
#  '101_5.jpg',
#  '101_6.jpg',
#  '101_7.jpg',
#  '101_8.jpg',
#  '101_9.jpg',
#  '102_1.jpg',
#  '102_2.jpg',
#  '102_3.jpg',
#  '102_4.jpg',
#  '102_5.jpg',
#  '102_6.jpg',
#  '102_7.jpg',
#  '102_8.jpg',
#  '102_9.jpg',
#  '103_1.jpg',
#  '103_2.jpg',
#  '103_3.jpg',
#  '103_4.jpg',
#  '103_5.jpg',
#  '103_6.jpg',
#  '103_7.jpg',
#  '103_8.jpg',
#  '103_9.jpg',
#  '104_1.jpg',
#  '104_10.jpg',
#  '104_11.jpg',
#  '104_12.jpg',
#  '104_2.jpg',
#  '104_3.jpg',
#  '104_4.jpg',
#  '104_5.jpg',
#  '104_6.jpg',
#  '104_7.jpg',
#  '104_8.jpg',
#  '104_9.jpg',
#  '105_1.jpg',
#  '105_2.jpg',
#  '105_3.jpg',
#  '105_4.jpg',
#  '105_5.jpg',
# ...

# %%
for i in fileList:
    print(i.split('_')[0])
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 102
# 102
# 102
# 102
# 102
# 102
# 102
# 102
# 102
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 104
# 104
# 104
# 104
# 104
# 104
# 104
# 104
# 104
# 104
# 104
# 104
# 105
# 105
# 105
# 105
# 105
# 105
# 105
# 105
# 105
# 106
# 106
# 106
# 106
# 106
# 106
# 106
# 106
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 108
# 108
# 108
# 109
# 109
# 109
# 109
# 109
# 109
# 109
# 109
# 10
# 10
# 10
# 110
# 110
# 110
# 110
# 110
# 110
# 110
# 110
# 110
# 110
# 110
# 110
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 113
# 113
# 113
# 113
# 113
# 113
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 116
# 116
# 116
# 116
# 116
# 116
# 117
# 117
# 117
# 117
# ...

# %%
fake = Faker(['it_IT', 'en_US', 'ja_JP','zh_CN','zh_TW'])

# %%
auctionsID='222-222-222-222-222'

# %%
my_config = Config(
    region_name = 'us-west-1',
    signature_version = 'v4',
    retries = {
        'max_attempts': 10,
        'mode': 'standard'
    }
)

# %%
client = boto3.client(
    'dynamodb',
    aws_access_key_id=os.getenv('awsAccessKeyId'),
    aws_secret_access_key=os.getenv('awsSecretAccessKey'),
    config=my_config)
dynamodb = boto3.resource(
    'dynamodb',
    aws_access_key_id=os.getenv('awsAccessKeyId'),
    aws_secret_access_key=os.getenv('awsSecretAccessKey'),
    config=my_config)
ddb_exceptions = client.exceptions

# %%
df.columns
# Out:
# Index(['lot', 'title', 'description', 'conditionReport', 'provenance',
#        'titleEng', 'descriptionEng', 'conditionReportEng', 'provenanceEng',
#        'reservePrice', 'startingPrice', 'estimatedPriceMin',
#        'estimatedPriceMax', 'comparison', 'reference'],
#       dtype='object')

# %%
auctionItemTable = dynamodb.Table('AuctionItem-7jzw3fqlhrcuzaarveonxbtczq-prod')
lotsTable=dynamodb.Table('Lot-7jzw3fqlhrcuzaarveonxbtczq-prod')

# %%
for i in range(df.shape[0]):
    # print(df.loc[i])
    createdAt=datetime.now().strftime("%Y-%m-%dT%H:%M:%S.000Z")
    auctionItemID=fake.uuid4()
    auctionItemData={'__typename': 'AuctionItem',
    'id':auctionItemID,
    'categoryAuctionItemsId':'未知',
    'description':df.loc[i]['description'],
    'name': df.loc[i]['title'],
    'title':df.loc[i]['title'],
    'titleEng':df.loc[i]['titleEng'],
    'descriptionEng':df.loc[i]['descriptionEng'],
    'conditionReport': df.loc[i]['conditionReport'],
    'conditionReportEng': df.loc[i]['conditionReportEng'],
    'provenance': df.loc[i]['provenance'],
    'provenanceEng': df.loc[i]['provenanceEng'],
    'reservePrice': df.loc[i]['reservePrice'],
    'comparison': df.loc[i]['comparison'],
    'reference': df.loc[i]['reference'],  
    'createdAt':createdAt,
    'updatedAt':createdAt
    }
    #print(data)
    imgList=[]
    for pictureName in fileList:
        if str(df.loc[i]['lot']) == str(pictureName.split('_')[0]):
            print( df.loc[i]['lot'], pictureName.split('_')[0])
            print('有啦有啦')
            imgList.append(f"""https://bhpmjsaa65d4d2254e4b41a89df0d66c611dc0144251-prod.s3.us-west-1.amazonaws.com/public/auction2/{pictureName}""")
    auctionItemData['imgUrls']=imgList
    print(auctionItemData)
    print('上传auctionitem 开始')
    response = auctionItemTable.put_item(Item=auctionItemData)
    print('上传auctionitem 结束')

    lotsData={'__typename': 'Lot',
    'id':fake.uuid4(),
    'lotOrder':int(df.loc[i]['lot']),
    'lotAuctionItemId':auctionItemID,
    'auctionLotId':auctionsID,
    'estimatedPriceMax':int(df.loc[i]['estimatedPriceMax']),
    'estimatedPriceMin':int(df.loc[i]['estimatedPriceMin']),
    'startingPrice':int(df.loc[i]['startingPrice']),
    'reservePrice':df.loc[i]['reservePrice'],
    'createdAt':createdAt,  
    'updatedAt':createdAt,  
    'lotStatus':'ComingSoon'
    }
    
    print(lotsData)
    print("上传lotsData")
    response = lotsTable.put_item(Item=lotsData)
    print('上传lotsData 结束')
# Out:
# 1 1
# 有啦有啦
# 1 1
# 有啦有啦
# 1 1
# 有啦有啦
# 1 1
# 有啦有啦
# 1 1
# 有啦有啦
# 1 1
# 有啦有啦
# 1 1
# 有啦有啦
# 1 1
# 有啦有啦
# 1 1
# 有啦有啦
# 1 1
# 有啦有啦
# ...

# %%
home_dev = dynamodb.Table('HomePageCarouse-o44se66l2zhuvdxs5ctmuxmmdy-dev')

# %%
response = home_dev.scan()

# %%
for i in response['Items']:
    print(i)
# Out:
# {'__typename': 'HomePageCarouse', 'updatedAt': '2022-04-23T04:04:27.736Z', 'createdAt': '2022-04-23T04:04:27.736Z', 'description': '来自北美和世界老收藏家的亚洲艺术盛会——宝华拍卖首拍，时间May 3, 2022 19:00 EST', 'id': 'e3dc1025-679c-48ee-94f8-2843bfc58c84', 'imgUrl': 'https://bhpmjsaa65d4d2254e4b41a89df0d66c611dc0144251-prod.s3.us-west-1.amazonaws.com/public/auction1/whole_2.jpg', 'auctionsID': 'fdfa3b15-1731-43fc-b23e-30c1707b954c', 'title': 'May 3, 2022 19:00 EST'}
# {'__typename': 'HomePageCarouse', 'updatedAt': '2022-04-23T04:04:07.894Z', 'createdAt': '2022-04-23T04:04:07.894Z', 'description': '来自北美和世界老收藏家的亚洲艺术盛会——宝华拍卖首拍，时间May 3, 2022 19:00 EST', 'id': 'b26d6a6c-7fb8-445c-81b4-da00e3718f59', 'imgUrl': 'https://bhpmjsaa65d4d2254e4b41a89df0d66c611dc0144251-prod.s3.us-west-1.amazonaws.com/public/auction1/whole_1.jpg', 'auctionsID': 'fdfa3b15-1731-43fc-b23e-30c1707b954c', 'title': 'May 3, 2022 19:00 EST'}
# ...

# %%
home_prod = dynamodb.Table('HomePageCarouse-ypfm6dynh5cedkkswzzr43yxfi-prod')

# %%
for i in response['Items']:
    print(i)

    home_prod.put_item(Item=i)
# Out:
# {'__typename': 'HomePageCarouse', 'updatedAt': '2022-04-23T04:04:27.736Z', 'createdAt': '2022-04-23T04:04:27.736Z', 'description': '来自北美和世界老收藏家的亚洲艺术盛会——宝华拍卖首拍，时间May 3, 2022 19:00 EST', 'id': 'e3dc1025-679c-48ee-94f8-2843bfc58c84', 'imgUrl': 'https://bhpmjsaa65d4d2254e4b41a89df0d66c611dc0144251-prod.s3.us-west-1.amazonaws.com/public/auction1/whole_2.jpg', 'auctionsID': 'fdfa3b15-1731-43fc-b23e-30c1707b954c', 'title': 'May 3, 2022 19:00 EST'}
# {'__typename': 'HomePageCarouse', 'updatedAt': '2022-04-23T04:04:07.894Z', 'createdAt': '2022-04-23T04:04:07.894Z', 'description': '来自北美和世界老收藏家的亚洲艺术盛会——宝华拍卖首拍，时间May 3, 2022 19:00 EST', 'id': 'b26d6a6c-7fb8-445c-81b4-da00e3718f59', 'imgUrl': 'https://bhpmjsaa65d4d2254e4b41a89df0d66c611dc0144251-prod.s3.us-west-1.amazonaws.com/public/auction1/whole_1.jpg', 'auctionsID': 'fdfa3b15-1731-43fc-b23e-30c1707b954c', 'title': 'May 3, 2022 19:00 EST'}
# ...
